# %% [markdown]
# # tab键看方法：

# %%
a =[1,2,3]
a
# Out:
# [1, 2, 3]

# %%
D:
# Out:
#   File "<ipython-input-2-095cd9e23682>", line 1
#     D:
#       ^
# SyntaxError: invalid syntax

# %%
a?

# %% [markdown]
# # %run直接运行文件

# %%
# %run D:tom.py
# Out:
# this is tom

# %%
# %paste
# Out:
# UsageError: Line magic function `%cpaste` not found.

# %%
import matplotlib.pylab as plt
lzx=plt.imread('D:\图片\heshui.jpg')
plt.imshow(lzx)

# %%
# %logstart
# Out:
# Activating auto-logging. Current session state plus future input saved.
# Filename       : ipython_log.py
# Mode           : rotate
# Output logging : False
# Raw input log  : False
# Timestamping   : False
# State          : active

# %%
def buhao():
    a=[1,2,3,4,5,6]
    c=[2,3,4,5,6,7]
    for i in a:
        c.append(i)
#     print (c)
def zhongdeng():
    a=[1,2,3,4,5,6]
    c=[2,3,4,5,6,7]
    c+=a
#     print(c)
def hao():
    a=[1,2,3,4,5,6]
    c=[2,3,4,5,6,7]
    c.extend(a)
#     print (c)

# %%
# %timeit buhao()
# %timeit zhongdeng()
# %timeit hao()
# Out:
# 764 ns ± 10 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
# 319 ns ± 17.3 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
# 426 ns ± 23.4 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
